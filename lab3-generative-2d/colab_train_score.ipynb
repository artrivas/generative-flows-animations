# %% [markdown]
# # Lab 3 — Paso 5b: entrenamiento completo de los 8 modelos de score (Colab, GPU T4)
#
# Entrena las 4 distribuciones × {eps, v} = 8 combinaciones hasta convergencia real (no la corrida corta de prueba del paso 5a).
#
# **Prerrequisito importante**: el código de `lab3-generative-2d/` debe estar *commiteado y pusheado* a `origin/main` en GitHub antes de correr la celda de clonado. Verifica localmente con `git status` / `git log`. Si el push todavía no se hizo, este notebook clonará una versión vieja/incompleta del repo.
#
# **Runtime**: Entorno de ejecución → Cambiar tipo de entorno de ejecución → GPU (T4).
#
# Al final, los 8 checkpoints se empaquetan en `checkpoints.zip` para descargar y copiar a `checkpoints/` localmente.

# %%
# !git clone https://github.com/artrivas/generative-flows-animations.git
# %cd generative-flows-animations/lab3-generative-2d

# %%
# !pip install -q -r requirements.txt

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
assert torch.cuda.is_available(), "GPU no habilitada -- Entorno de ejecución > Cambiar tipo de entorno de ejecución > GPU"

# %% [markdown]
# ## Entrenamiento — 8 combinaciones (4 distribuciones × {eps, v})
#
# Hiperparámetros para convergencia real: `--steps 30000 --batch_size 512 --lr 1e-3 --seed 0`. Cada celda es independiente -- si una falla o se interrumpe, puede volver a correrse sola sin afectar a las demás. `device` es agnóstico (usa la GPU automáticamente).

# %%
# !python -m src.training.train_score --distribution eight_gaussians --param eps \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution eight_gaussians --param v \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution two_moons --param eps \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution two_moons --param v \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution checkerboard --param eps \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution checkerboard --param v \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution pinwheel --param eps \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %%
# !python -m src.training.train_score --distribution pinwheel --param v \
    --steps 30000 --batch_size 512 --lr 1e-3 --seed 0 --log_every 1000 --output-dir checkpoints

# %% [markdown]
# ## Empaquetar y descargar los checkpoints
#
# Descarga `checkpoints.zip` y descomprime su contenido dentro de `lab3-generative-2d/checkpoints/` en el entorno local.

# %%
import shutil
shutil.make_archive("checkpoints", "zip", "checkpoints")

from google.colab import files
files.download("checkpoints.zip")
